# %%
#[99,86,87,8,8,8,111,87,77,85]
#numerical data  ex 1,2,3;
#categorical data ex colours
#ordinal data ex school grades a,b,c
import numpy
x=[99,86,87,888,111,87,77,85]

mean = numpy.mean(x)
print("Mean=",mean)

meidan =numpy.median(x)
print("Median=",meidan)

from scipy import stats

mode=stats.mode(x)
print("mode=",mode)

standard_deviation=numpy.std(x)
print("STD= ",standard_deviation)

var=standard_deviation**2
varience=numpy.var(x)
print("varience = ",var)
print("varience = ",varience)

percentile=numpy.percentile(x,75)
print("percentile= ",percentile)
# Out:
# Mean= 190.0
# Median= 87.0
# mode= ModeResult(mode=87, count=2)
# STD=  263.996685585255
# varience =  69694.25
# varience =  69694.25
# percentile=  102.0

# %%
#line graph
import matplotlib.pyplot as plt
x=numpy.array([0,11])
y=numpy.array([0,256])
plt.plot(x,y)
plt.show()

# %%
#bar graph
import numpy
import matplotlib.pyplot as plt
x1=numpy.array(['A','B','C','D'])
y1=numpy.array([1,3,4,5])
plt.bar(x1,y1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#random histogram
import numpy
import matplotlib.pyplot
x=numpy.random.normal(170,23,55)
plt.hist(x)
plt.show()

# %%
#scatter graph
x2=numpy.array([5,7,8,9,12,34,6,23,67])
y2=numpy.array([45,67,23,12,3,67,90,34,89])
plt.scatter(x2,y2)
plt.show()

plt.scatter(y2,x2)
plt.show()

# %%
#line graph
y3=numpy.array([3,8,5,6,-3,-2,10])
plt.plot(y3,linestyle='dotted')
plt.show()

# %%
y3=numpy.array([3,8,5,6,-3,-2,10])
plt.plot(y3)
plt.show()

# %%
# pie chart
y4=numpy.array([35,25,15,25])
plt.pie(y4)
plt.show()

# %%
y4=numpy.array([35,25,15,25])
x4=['Apple','Banana','orange','strauberry']
plt.pie(y4,labels=x4)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
y3=numpy.array([3,8,5,6,-3,-2,10])
plt.plot(y3,marker="o")

plt.show()
